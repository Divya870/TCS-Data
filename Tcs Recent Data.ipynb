# %% [markdown]
# <a href="https://colab.research.google.com/github/Divya870/TCS-Data/blob/main/Tcs%20Recent%20Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import yfinance as yf

# %%
tcs=yf.download('TCS.NS',
  start='2020-01-01',
  end='2025-02-25',
  progress=False)

# %%
tcs
# Out:
# Price             Close         High          Low         Open   Volume
# Ticker           TCS.NS       TCS.NS       TCS.NS       TCS.NS   TCS.NS
# Date
# 2020-01-01  1944.477173  1959.099150  1932.277008  1944.835911  1354908
# 2020-01-02  1935.550903  1955.555483  1927.970753  1955.555483  2380752
# 2020-01-03  1974.124878  1994.174357  1941.247552  1941.247552  4655761
# 2020-01-06  1973.944946  1996.820084  1962.686746  1978.026632  3023209
# 2020-01-07  1978.789917  1986.683910  1959.009600  1973.990534  2429317
# ...                 ...          ...          ...          ...      ...
# 2025-02-18  3873.199951  3924.399902  3864.500000  3898.399902  2149879
# 2025-02-19  3784.100098  3874.949951  3768.149902  3872.199951  4366672
# 2025-02-20  3779.399902  3788.000000  3751.300049  3761.500000  2888572
# 2025-02-21  3786.000000  3817.000000  3775.000000  3776.100098  1833931
# 2025-02-24  3675.600098  3763.199951  3670.000000  3743.149902  2508516
#
# [1278 rows x 5 columns]

# %%
tcs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1278 entries, 2020-01-01 to 2025-02-24
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   (Close, TCS.NS)   1278 non-null   float64
#  1   (High, TCS.NS)    1278 non-null   float64
#  2   (Low, TCS.NS)     1278 non-null   float64
#  3   (Open, TCS.NS)    1278 non-null   float64
#  4   (Volume, TCS.NS)  1278 non-null   int64
# dtypes: float64(4), int64(1)
# memory usage: 59.9 KB

# %%
tcs['Close'].plot(figsize=(12,8))
# Out:
# <Axes: xlabel='Date'>

# %%
tcs['Volume'].plot(figsize=(12,8))
# Out:
# <Axes: xlabel='Date'>

# %%
tcs[['Close','Volume']].plot(subplots=True,style='b',figsize=(12,8))
# Out:
# array([<Axes: xlabel='Date'>, <Axes: xlabel='Date'>], dtype=object)

# %%
tcs.describe()
# Out:
# Price         Close         High          Low         Open        Volume
# Ticker       TCS.NS       TCS.NS       TCS.NS       TCS.NS        TCS.NS
# count   1278.000000  1278.000000  1278.000000  1278.000000  1.278000e+03
# mean    3137.756908  3168.802174  3108.369093  3138.873308  2.674493e+06
# std      678.401764   681.448465   675.547818   678.541455  1.661432e+06
# min     1481.994263  1526.462673  1354.091684  1412.574580  1.548950e+05
# 25%     2863.389343  2892.679005  2831.539196  2864.958926  1.659072e+06
# 50%     3175.641479  3198.236315  3147.976078  3169.840793  2.205158e+06
# 75%     3549.663025  3576.972573  3517.535275  3551.448396  3.143370e+06
# max     4471.390137  4509.193819  4430.394634  4493.237112  1.983933e+07

# %%
tcs.isnull()
# Out:
# Price       Close   High    Low   Open Volume
# Ticker     TCS.NS TCS.NS TCS.NS TCS.NS TCS.NS
# Date
# 2020-01-01  False  False  False  False  False
# 2020-01-02  False  False  False  False  False
# 2020-01-03  False  False  False  False  False
# 2020-01-06  False  False  False  False  False
# 2020-01-07  False  False  False  False  False
# ...           ...    ...    ...    ...    ...
# 2025-02-18  False  False  False  False  False
# 2025-02-19  False  False  False  False  False
# 2025-02-20  False  False  False  False  False
# 2025-02-21  False  False  False  False  False
# 2025-02-24  False  False  False  False  False
#
# [1278 rows x 5 columns]

# %%
tcs.isnull().sum()
# Out:
# Price   Ticker
# Close   TCS.NS    0
# High    TCS.NS    0
# Low     TCS.NS    0
# Open    TCS.NS    0
# Volume  TCS.NS    0
# dtype: int64

# %%
tcs['simple_rtn']=tcs.Close.pct_change()
tcs['simple_rtn']
# Out:
# Date
# 2020-01-01         NaN
# 2020-01-02   -0.004591
# 2020-01-03    0.019929
# 2020-01-06   -0.000091
# 2020-01-07    0.002454
#                 ...
# 2025-02-18   -0.008016
# 2025-02-19   -0.023004
# 2025-02-20   -0.001242
# 2025-02-21    0.001746
# 2025-02-24   -0.029160
# Name: simple_rtn, Length: 1278, dtype: float64

# %%
tcs['log_rtn']=np.log(tcs.Close/tcs.Close.shift(1))
tcs['log_rtn']
# Out:
# Date
# 2020-01-01         NaN
# 2020-01-02   -0.004601
# 2020-01-03    0.019733
# 2020-01-06   -0.000091
# 2020-01-07    0.002451
#                 ...
# 2025-02-18   -0.008049
# 2025-02-19   -0.023273
# 2025-02-20   -0.001243
# 2025-02-21    0.001745
# 2025-02-24   -0.029594
# Name: log_rtn, Length: 1278, dtype: float64

# %%
tcs['vsimple_rtn']=tcs.Volume.pct_change()
tcs['vsimple_rtn']
# Out:
# Date
# 2020-01-01         NaN
# 2020-01-02    0.757132
# 2020-01-03    0.955584
# 2020-01-06   -0.350652
# 2020-01-07   -0.196444
#                 ...
# 2025-02-18    0.194506
# 2025-02-19    1.031125
# 2025-02-20   -0.338496
# 2025-02-21   -0.365108
# 2025-02-24    0.367836
# Name: vsimple_rtn, Length: 1278, dtype: float64

# %%
tcs
# Out:
# Price             Close         High          Low         Open   Volume  \
# Ticker           TCS.NS       TCS.NS       TCS.NS       TCS.NS   TCS.NS
# Date
# 2020-01-01  1944.477173  1959.099150  1932.277008  1944.835911  1354908
# 2020-01-02  1935.550903  1955.555483  1927.970753  1955.555483  2380752
# 2020-01-03  1974.124878  1994.174357  1941.247552  1941.247552  4655761
# 2020-01-06  1973.944946  1996.820084  1962.686746  1978.026632  3023209
# 2020-01-07  1978.789917  1986.683910  1959.009600  1973.990534  2429317
# ...                 ...          ...          ...          ...      ...
# 2025-02-18  3873.199951  3924.399902  3864.500000  3898.399902  2149879
# 2025-02-19  3784.100098  3874.949951  3768.149902  3872.199951  4366672
# 2025-02-20  3779.399902  3788.000000  3751.300049  3761.500000  2888572
# 2025-02-21  3786.000000  3817.000000  3775.000000  3776.100098  1833931
# 2025-02-24  3675.600098  3763.199951  3670.000000  3743.149902  2508516
#
# ...

# %%
tcs[['simple_rtn','vsimple_rtn']].plot(subplots=True,style='b',figsize=(12,8))
# Out:
# array([<Axes: xlabel='Date'>, <Axes: xlabel='Date'>], dtype=object)

# %%
tcs
# Out:
# Price             Close         High          Low         Open   Volume  \
# Ticker           TCS.NS       TCS.NS       TCS.NS       TCS.NS   TCS.NS
# Date
# 2020-01-01  1944.477173  1959.099150  1932.277008  1944.835911  1354908
# 2020-01-02  1935.550903  1955.555483  1927.970753  1955.555483  2380752
# 2020-01-03  1974.124878  1994.174357  1941.247552  1941.247552  4655761
# 2020-01-06  1973.944946  1996.820084  1962.686746  1978.026632  3023209
# 2020-01-07  1978.789917  1986.683910  1959.009600  1973.990534  2429317
# ...                 ...          ...          ...          ...      ...
# 2025-02-18  3873.199951  3924.399902  3864.500000  3898.399902  2149879
# 2025-02-19  3784.100098  3874.949951  3768.149902  3872.199951  4366672
# 2025-02-20  3779.399902  3788.000000  3751.300049  3761.500000  2888572
# 2025-02-21  3786.000000  3817.000000  3775.000000  3776.100098  1833931
# 2025-02-24  3675.600098  3763.199951  3670.000000  3743.149902  2508516
#
# ...

# %%
tcs['vlog_rtn']=np.log(tcs.Volume/tcs.Volume.shift(1))
tcs
# Out:
# Price             Close         High          Low         Open   Volume  \
# Ticker           TCS.NS       TCS.NS       TCS.NS       TCS.NS   TCS.NS
# Date
# 2020-01-01  1944.477173  1959.099150  1932.277008  1944.835911  1354908
# 2020-01-02  1935.550903  1955.555483  1927.970753  1955.555483  2380752
# 2020-01-03  1974.124878  1994.174357  1941.247552  1941.247552  4655761
# 2020-01-06  1973.944946  1996.820084  1962.686746  1978.026632  3023209
# 2020-01-07  1978.789917  1986.683910  1959.009600  1973.990534  2429317
# ...                 ...          ...          ...          ...      ...
# 2025-02-18  3873.199951  3924.399902  3864.500000  3898.399902  2149879
# 2025-02-19  3784.100098  3874.949951  3768.149902  3872.199951  4366672
# 2025-02-20  3779.399902  3788.000000  3751.300049  3761.500000  2888572
# 2025-02-21  3786.000000  3817.000000  3775.000000  3776.100098  1833931
# 2025-02-24  3675.600098  3763.199951  3670.000000  3743.149902  2508516
#
# ...

# %%
tcs[['log_rtn','vlog_rtn']].plot(subplots=True,style='b',figsize=(12,8))
# Out:
# array([<Axes: xlabel='Date'>, <Axes: xlabel='Date'>], dtype=object)

# %%
tcs[['log_rtn','simple_rtn']].plot(subplots=True,style='b',figsize=(12,8))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-157-f8afb57dd836> in <cell line: 0>()
# ----> 1 tcs[['log_rtn','simple_rtn']].plot(subplots=True,style='b',figsize=(12,8))
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4106             if is_iterator(key):
#    4107                 key = list(key)
# -> 4108             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4109
#    4110         # take() does not accept boolean indexers
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/multi.py in _get_indexer_strict(self, key, axis_name)
#    2761             indexer = self._get_indexer_level_0(keyarr)
#    2762
# -> 2763             self._raise_if_missing(key, indexer, axis_name)
#    2764             return self[indexer], indexer
#    2765
#
# ...

# %%
WINDOW_SIZE=12
tcs['rolling_mean']=tcs.Close.rolling(window=WINDOW_SIZE).mean()
tcs['rolling_std']=tcs.Close.rolling(window=WINDOW_SIZE).std()

# %%
tcs
# Out:
# Price             Close         High          Low         Open   Volume  \
# Ticker           TCS.NS       TCS.NS       TCS.NS       TCS.NS   TCS.NS
# Date
# 2020-01-01  1944.477173  1959.099150  1932.277008  1944.835911  1354908
# 2020-01-02  1935.550903  1955.555483  1927.970753  1955.555483  2380752
# 2020-01-03  1974.124878  1994.174357  1941.247552  1941.247552  4655761
# 2020-01-06  1973.944946  1996.820084  1962.686746  1978.026632  3023209
# 2020-01-07  1978.789917  1986.683910  1959.009600  1973.990534  2429317
# ...                 ...          ...          ...          ...      ...
# 2025-02-18  3873.199951  3924.399902  3864.500000  3898.399902  2149879
# 2025-02-19  3784.100098  3874.949951  3768.149902  3872.199951  4366672
# 2025-02-20  3779.399902  3788.000000  3751.300049  3761.500000  2888572
# 2025-02-21  3786.000000  3817.000000  3775.000000  3776.100098  1833931
# 2025-02-24  3675.600098  3763.199951  3670.000000  3743.149902  2508516
#
# ...

# %%
WINDOW_SIZE=12
tcs['vrolling_mean']=tcs.Volume.rolling(window=WINDOW_SIZE).mean()
tcs['vrolling_std']=tcs.Volume.rolling(window=WINDOW_SIZE).std()

# %%
tcs
# Out:
# Price             Close         High          Low         Open   Volume  \
# Ticker           TCS.NS       TCS.NS       TCS.NS       TCS.NS   TCS.NS
# Date
# 2020-01-01  1944.477173  1959.099150  1932.277008  1944.835911  1354908
# 2020-01-02  1935.550903  1955.555483  1927.970753  1955.555483  2380752
# 2020-01-03  1974.124878  1994.174357  1941.247552  1941.247552  4655761
# 2020-01-06  1973.944946  1996.820084  1962.686746  1978.026632  3023209
# 2020-01-07  1978.789917  1986.683910  1959.009600  1973.990534  2429317
# ...                 ...          ...          ...          ...      ...
# 2025-02-18  3873.199951  3924.399902  3864.500000  3898.399902  2149879
# 2025-02-19  3784.100098  3874.949951  3768.149902  3872.199951  4366672
# 2025-02-20  3779.399902  3788.000000  3751.300049  3761.500000  2888572
# 2025-02-21  3786.000000  3817.000000  3775.000000  3776.100098  1833931
# 2025-02-24  3675.600098  3763.199951  3670.000000  3743.149902  2508516
#
# ...

# %%
tcs[0:20]
# Out:
# Price             Close         High          Low         Open   Volume  \
# Ticker           TCS.NS       TCS.NS       TCS.NS       TCS.NS   TCS.NS
# Date
# 2020-01-01  1944.477173  1959.099150  1932.277008  1944.835911  1354908
# 2020-01-02  1935.550903  1955.555483  1927.970753  1955.555483  2380752
# 2020-01-03  1974.124878  1994.174357  1941.247552  1941.247552  4655761
# 2020-01-06  1973.944946  1996.820084  1962.686746  1978.026632  3023209
# 2020-01-07  1978.789917  1986.683910  1959.009600  1973.990534  2429317
# 2020-01-08  2023.103882  2027.364936  1975.380114  1978.026409  5197454
# 2020-01-09  1986.414307  2020.143791  1982.511990  2017.273229  3734173
# 2020-01-10  1985.697021  2004.041945  1980.718270  1998.659559  1915807
# 2020-01-13  1964.884888  1990.540795  1959.816343  1989.554156  2843893
# 2020-01-14  1979.731445  2000.274353  1969.056466  1969.056466  2948452
# 2020-01-15  1997.672729  2001.350781  1968.338766  1985.203621  2620681
# ...

# %%
WINDOW_SIZE=10
tcs['rolling_mean']=tcs.Close.rolling(window=WINDOW_SIZE).mean()
tcs['rolling_std']=tcs.Close.rolling(window=WINDOW_SIZE).std()

# %%
tcs
# Out:
# Price             Close         High          Low         Open   Volume  \
# Ticker           TCS.NS       TCS.NS       TCS.NS       TCS.NS   TCS.NS
# Date
# 2020-01-01  1944.477173  1959.099150  1932.277008  1944.835911  1354908
# 2020-01-02  1935.550903  1955.555483  1927.970753  1955.555483  2380752
# 2020-01-03  1974.124878  1994.174357  1941.247552  1941.247552  4655761
# 2020-01-06  1973.944946  1996.820084  1962.686746  1978.026632  3023209
# 2020-01-07  1978.789917  1986.683910  1959.009600  1973.990534  2429317
# ...                 ...          ...          ...          ...      ...
# 2025-02-18  3873.199951  3924.399902  3864.500000  3898.399902  2149879
# 2025-02-19  3784.100098  3874.949951  3768.149902  3872.199951  4366672
# 2025-02-20  3779.399902  3788.000000  3751.300049  3761.500000  2888572
# 2025-02-21  3786.000000  3817.000000  3775.000000  3776.100098  1833931
# 2025-02-24  3675.600098  3763.199951  3670.000000  3743.149902  2508516
#
# ...

# %%
tcs.head(20)
# Out:
# Price             Close         High          Low         Open   Volume  \
# Ticker           TCS.NS       TCS.NS       TCS.NS       TCS.NS   TCS.NS
# Date
# 2020-01-01  1944.477173  1959.099150  1932.277008  1944.835911  1354908
# 2020-01-02  1935.550903  1955.555483  1927.970753  1955.555483  2380752
# 2020-01-03  1974.124878  1994.174357  1941.247552  1941.247552  4655761
# 2020-01-06  1973.944946  1996.820084  1962.686746  1978.026632  3023209
# 2020-01-07  1978.789917  1986.683910  1959.009600  1973.990534  2429317
# 2020-01-08  2023.103882  2027.364936  1975.380114  1978.026409  5197454
# 2020-01-09  1986.414307  2020.143791  1982.511990  2017.273229  3734173
# 2020-01-10  1985.697021  2004.041945  1980.718270  1998.659559  1915807
# 2020-01-13  1964.884888  1990.540795  1959.816343  1989.554156  2843893
# 2020-01-14  1979.731445  2000.274353  1969.056466  1969.056466  2948452
# 2020-01-15  1997.672729  2001.350781  1968.338766  1985.203621  2620681
# ...

# %%
tcs[['rolling_mean','vrolling_mean']].plot(subplots=True,style='b',figsize=(12,8))
# Out:
# array([<Axes: xlabel='Date'>, <Axes: xlabel='Date'>], dtype=object)

# %%
tcs['logrolling_mean']=np.log(tcs.rolling_mean/tcs.rolling_mean.shift(1))
tcs['logrolling_std']=np.log(tcs.rolling_std/tcs.rolling_std.shift(1))
tcs
# Out:
# Price             Close         High          Low         Open   Volume  \
# Ticker           TCS.NS       TCS.NS       TCS.NS       TCS.NS   TCS.NS
# Date
# 2020-01-01  1944.477173  1959.099150  1932.277008  1944.835911  1354908
# 2020-01-02  1935.550903  1955.555483  1927.970753  1955.555483  2380752
# 2020-01-03  1974.124878  1994.174357  1941.247552  1941.247552  4655761
# 2020-01-06  1973.944946  1996.820084  1962.686746  1978.026632  3023209
# 2020-01-07  1978.789917  1986.683910  1959.009600  1973.990534  2429317
# ...                 ...          ...          ...          ...      ...
# 2025-02-18  3873.199951  3924.399902  3864.500000  3898.399902  2149879
# 2025-02-19  3784.100098  3874.949951  3768.149902  3872.199951  4366672
# 2025-02-20  3779.399902  3788.000000  3751.300049  3761.500000  2888572
# 2025-02-21  3786.000000  3817.000000  3775.000000  3776.100098  1833931
# 2025-02-24  3675.600098  3763.199951  3670.000000  3743.149902  2508516
#
# ...

# %%
tcs['logvrolling_mean']=np.log(tcs.vrolling_mean/tcs.vrolling_mean.shift(1))
tcs['logvrolling_std']=np.log(tcs.vrolling_std/tcs.vrolling_std.shift(1))
tcs
# Out:
# Price             Close         High          Low         Open   Volume  \
# Ticker           TCS.NS       TCS.NS       TCS.NS       TCS.NS   TCS.NS
# Date
# 2020-01-01  1944.477173  1959.099150  1932.277008  1944.835911  1354908
# 2020-01-02  1935.550903  1955.555483  1927.970753  1955.555483  2380752
# 2020-01-03  1974.124878  1994.174357  1941.247552  1941.247552  4655761
# 2020-01-06  1973.944946  1996.820084  1962.686746  1978.026632  3023209
# 2020-01-07  1978.789917  1986.683910  1959.009600  1973.990534  2429317
# ...                 ...          ...          ...          ...      ...
# 2025-02-18  3873.199951  3924.399902  3864.500000  3898.399902  2149879
# 2025-02-19  3784.100098  3874.949951  3768.149902  3872.199951  4366672
# 2025-02-20  3779.399902  3788.000000  3751.300049  3761.500000  2888572
# 2025-02-21  3786.000000  3817.000000  3775.000000  3776.100098  1833931
# 2025-02-24  3675.600098  3763.199951  3670.000000  3743.149902  2508516
#
# ...

# %%
tcs[['logrolling_mean','logrolling_std']].plot(subplots=True,style='b',figsize=(12,8))
# Out:
# array([<Axes: xlabel='Date'>, <Axes: xlabel='Date'>], dtype=object)

# %%
tcs[['logvrolling_mean','logvrolling_std']].plot(subplots=True,style='b',figsize=(12,8))
# Out:
# array([<Axes: xlabel='Date'>, <Axes: xlabel='Date'>], dtype=object)

# %%
tcs[['logrolling_mean','logvrolling_mean']].plot(subplots=True,style='b',figsize=(12,8))
# Out:
# array([<Axes: xlabel='Date'>, <Axes: xlabel='Date'>], dtype=object)

# %%
tcs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1278 entries, 2020-01-01 to 2025-02-24
# Data columns (total 16 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   (Close, TCS.NS)       1278 non-null   float64
#  1   (High, TCS.NS)        1278 non-null   float64
#  2   (Low, TCS.NS)         1278 non-null   float64
#  3   (Open, TCS.NS)        1278 non-null   float64
#  4   (Volume, TCS.NS)      1278 non-null   int64
#  5   (rolling_mean, )      1267 non-null   float64
#  6   (rolling_std, )       1267 non-null   float64
#  7   (vrolling_mean, )     1267 non-null   float64
#  8   (vrolling_std, )      1267 non-null   float64
#  9   (logrolling_mean, )   1266 non-null   float64
#  10  (logrolling_std, )    1266 non-null   float64
#  11  (logvrolling_mean, )  1266 non-null   float64
#  12  (logvrolling_std, )   1266 non-null   float64
#  13  (simple_rtn, )        1277 non-null   float64
# ...

# %%
tcs
# Out:
# Price             Close         High          Low         Open   Volume  \
# Ticker           TCS.NS       TCS.NS       TCS.NS       TCS.NS   TCS.NS
# Date
# 2020-01-01  1944.477173  1959.099150  1932.277008  1944.835911  1354908
# 2020-01-02  1935.550903  1955.555483  1927.970753  1955.555483  2380752
# 2020-01-03  1974.124878  1994.174357  1941.247552  1941.247552  4655761
# 2020-01-06  1973.944946  1996.820084  1962.686746  1978.026632  3023209
# 2020-01-07  1978.789917  1986.683910  1959.009600  1973.990534  2429317
# ...                 ...          ...          ...          ...      ...
# 2025-02-18  3873.199951  3924.399902  3864.500000  3898.399902  2149879
# 2025-02-19  3784.100098  3874.949951  3768.149902  3872.199951  4366672
# 2025-02-20  3779.399902  3788.000000  3751.300049  3761.500000  2888572
# 2025-02-21  3786.000000  3817.000000  3775.000000  3776.100098  1833931
# 2025-02-24  3675.600098  3763.199951  3670.000000  3743.149902  2508516
#
# ...

# %%
tcs[['logrolling_std','logvrolling_std']].plot(subplots=True,style='b',figsize=(12,8))
# Out:
# array([<Axes: xlabel='Date'>, <Axes: xlabel='Date'>], dtype=object)
